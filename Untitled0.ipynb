# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayshfby/HTML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread("totoro.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
from google.colab import files

uploaded = files.upload()
img = cv2.imread(uploaded)
cv2_imshow(img)
# Out:
#      <input type="file" id="files-75b05b59-b61d-43d6-98ab-427694d34e62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75b05b59-b61d-43d6-98ab-427694d34e62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
height, width, channel = img.shape
print("lebar gambar:", width)
print("tinggi gambar:", height)
print("jumlah saluran:", channel)
# Out:
# lebar gambar: 1200
# tinggi gambar: 800
# jumlah saluran: 3

# %%
img2 = cv2.imread("ghibli.jpg")
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=750x405>

# %%
# !pip install rembg

# Agar pustaka ini berfungsi dengan baik, kita juga harus menentukan versi pustaka yang diperlukan!
# !pip install Pillow==9.0.0

# %%
rembg --help
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eb489558ff95> in <cell line: 1>()
# ----> 1 rembg --help
#
# NameError: name 'rembg' is not defined

# %%
import numpy as np

def change_back(background, img):
    """Sebuah fungsi yang mengganti latar belakang gambar dengan gambar lain.
    Menerima dua argumen: gambar latar belakang (background) dan gambar itu sendiri (img).
    Fungsi akan dimulai dari sudut kiri atas gambar. Ia akan mencari semua piksel hitam (dengan nilai 0)
    dan menggantinya dengan piksel dari gambar latar belakang"""

    x, y = 0, 0

    # Ensure the background is resized to match the img dimensions
    background = cv2.resize(background, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_AREA)

    # Create a copy of the resized background
    res = np.copy(background)

    # Extract the region of interest (ROI) from the background
    place = res[y: y + img.shape[0], x: x + img.shape[1]]

    # Ensure the img has an alpha channel
    if img.shape[2] == 4:
        # Extract the alpha channel and repeat it across the color channels
        alpha_channel = img[..., 3]  # Extract the alpha channel
        alpha_channel = alpha_channel[..., np.newaxis]  # Add new axis for broadcasting
        alpha_channel = np.repeat(alpha_channel, 3, axis=2)  # Repeat it across the color channels
        alpha_channel = alpha_channel.astype('uint16')

        # Blend the images using the alpha channel
        place[...] = (place.astype('uint16') * (255 - alpha_channel) // 255) + (img[..., :3].astype('uint16') * alpha_channel // 255)

    return res

# %%
change_back(img,img2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-44e0bd9ccf97> in <cell line: 1>()
# ----> 1 change_back(img,img2)
#
# <ipython-input-1-7f0e5fd2e48c> in change_back(background, img)
#      12     place = res[y: y + img.shape[0], x: x + img.shape[1]]
#      13     a = img[..., 3:].repeat(3, axis=2).astype('uint16')
# ---> 14     place[...] = (place.astype('uint16') * (255 - a) // 255) + img[..., :3].astype('uint16') * a // 255
#      15     return res
#
# ValueError: operands could not be broadcast together with shapes (405,750,3) (405,750,0)
